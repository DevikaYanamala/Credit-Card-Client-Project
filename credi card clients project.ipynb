# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:/Users/devik/Downloads/default_of_credit_card_clients_0.xlsx")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2      0      0
# 1   2     120000    2          2         2   26      0      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.MARRIAGE.unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
df.LIMIT_BAL.unique()
# Out:
# array([  20000,  120000,   90000,   50000,  500000,  100000,  140000,
#         200000,  260000,  630000,   70000,  250000,  320000,  360000,
#         180000,  130000,  450000,   60000,  230000,  160000,  280000,
#          10000,   40000,  210000,  150000,  380000,  310000,  400000,
#          80000,  290000,  340000,  300000,   30000,  240000,  470000,
#         480000,  350000,  330000,  110000,  420000,  170000,  370000,
#         270000,  220000,  190000,  510000,  460000,  440000,  410000,
#         490000,  390000,  580000,  600000,  620000,  610000,  700000,
#         670000,  680000,  430000,  550000,  540000, 1000000,  530000,
#         710000,  560000,  520000,  750000,  640000,   16000,  570000,
#         590000,  660000,  720000,  327680,  740000,  800000,  760000,
#         690000,  650000,  780000,  730000], dtype=int64)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Sample data
dates = ['PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
amounts = ['PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

plt.plot(dates, amounts, marker='o')
plt.title('Outstanding Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Outstanding Amount')
plt.grid(True)
plt.show()

# %%
plt.xlabel("Age")
plt.ylabel("outstanding amount")
plt.scatter(df['AGE'],df['PAY_AMT6'])

# %% [markdown]
# OBSERVATION:
#
# Outstanding income is not impacted by Age.

# %%
plt.xlabel("Marriage")
plt.ylabel("outstanding amount")
plt.bar(df['MARRIAGE'], df['PAY_AMT3'])
# Out:
# <BarContainer object of 30000 artists>

# %% [markdown]
# OBSERVATION:
#
# Outstanding income is impacted by Marraige.and most repayment is doing by married and others than other category

# %%
plt.xlabel("Education")
plt.ylabel("outstanding amount")
plt.bar(df['EDUCATION'], df['PAY_AMT3'])
# Out:
# <BarContainer object of 30000 artists>

# %% [markdown]
# Graduate school people doing repayment more than others

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df[['LIMIT_BAL']])
df['LIMIT_BAL']=scaler.transform(df[['LIMIT_BAL']])

scaler.fit(df[['PAY_AMT5']])
df['PAY_AMT5']=scaler.transform(df[['PAY_AMT5']])

# %%
plt.figure(figsize=(10, 6))
plt.xlabel("credit limt")
plt.ylabel("outstanding amount")
plt.bar(df['LIMIT_BAL'],df['PAY_AMT5'])
# Out:
# <BarContainer object of 30000 artists>

# %%
dates = ['PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
amounts = ['PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

plt.scatter(dates, amounts, marker='o')
plt.title('Outstanding Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Outstanding Amount')
# Out:
# Text(0, 0.5, 'Outstanding Amount')

# %%
import numpy as np
import scipy.stats as st

# %%
st.norm.interval(confidence=0.95, loc=np.mean(df['default payment next month']))
# Out:
# (-1.738763984540054, 2.181163984540054)

# %%
plt.xlabel("next month payment")
plt.ylabel("outstanding amount") 
plt.scatter(df['default payment next month'],df['PAY_AMT1'])

# %% [markdown]
# OBSERVATION:
#
# Next payment mostly they will pay

# %%
pdb=df["default payment next month"].mode()

# %%
pdb
# Out:
# 0    0
# Name: default payment next month, dtype: int64

# %%
pdb_per=df["default payment next month"].unique()

# %%
pdb_per
# Out:
# array([1, 0], dtype=int64)

# %%
from scipy.stats import poisson,expon
from scipy import stats

# %%
stats.binom.pmf(0,2,0.01)
# Out:
# 0.9801000000000002

# %%
stats.binom.pmf(1,2,0.01)
# Out:
# 0.0198

# %% [markdown]
# OBSERVATION:
#
# Based on above we conclude that mostly people will pay
